# %%
import pandas as pd

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
foods = [
    ('Fruit', 'Apple'),
    ('Fruit', 'Banana'),
    ('Vegetable', 'Broccoli'),
    ('Vegetable', 'Tomato')
]

datas = [
    (3, 200, 95),
    (2, 130, 105),
    (5, 230, 50),
    (7, 310, 22)
]

mi = pd.MultiIndex.from_tuples(tuples = foods, names = ['Group', 'Item'])

store = pd.DataFrame(data = datas, columns = ['Price', 'Weight', 'Calorie'], index = mi)

store
# Out:
#                     Price  Weight  Calorie
# Group     Item
# Fruit     Apple         3     200       95
#           Banana        2     130      105
# Vegetable Broccoli      5     230       50
#           Tomato        7     310       22
