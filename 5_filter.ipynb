# %%
import pandas as pd

# %%
ep = pd.read_csv('data/employees.csv', parse_dates=['Start Date'])
ep
# Out:
#      First Name  Gender Start Date    Salary   Mgmt          Team
# 0       Douglas    Male 1993-08-06       NaN   True     Marketing
# 1        Thomas    Male 1996-03-31   61933.0   True           NaN
# 2         Maria  Female        NaT  130590.0  False       Finance
# 3         Jerry     NaN 2005-03-04  138705.0   True       Finance
# 4         Larry    Male 1998-01-24  101004.0   True            IT
# ...         ...     ...        ...       ...    ...           ...
# 996     Phillip    Male 1984-01-31   42392.0  False       Finance
# 997     Russell    Male 2013-05-20   96914.0  False       Product
# 998       Larry    Male 2013-04-20   60500.0  False  Business Dev
# 999      Albert    Male 2012-05-15  129949.0   True         Sales
# 1000        NaN     NaN        NaT       NaN    NaN           NaN
#
# [1001 rows x 6 columns]

# %%
ep['First Name'] == 'Maria'
# Out:
# 0       False
# 1       False
# 2        True
# 3       False
# 4       False
#         ...
# 996     False
# 997     False
# 998     False
# 999     False
# 1000    False
# Name: First Name, Length: 1001, dtype: bool

# %%
ep[ep['First Name'] == 'Maria']
# Out:
#     First Name  Gender Start Date    Salary   Mgmt          Team
# 2        Maria  Female        NaT  130590.0  False       Finance
# 198      Maria  Female 1990-12-27   36067.0   True       Product
# 815      Maria     NaN 1986-01-18  106562.0  False            HR
# 844      Maria     NaN 1985-06-19  148857.0  False         Legal
# 936      Maria  Female 2003-03-14   96250.0  False  Business Dev
# 984      Maria  Female 2011-10-15   43455.0  False   Engineering

# %%
ep[ep['Team'] != 'Finance']
# Out:
#      First Name  Gender Start Date    Salary   Mgmt          Team
# 0       Douglas    Male 1993-08-06       NaN   True     Marketing
# 1        Thomas    Male 1996-03-31   61933.0   True           NaN
# 4         Larry    Male 1998-01-24  101004.0   True            IT
# 5        Dennis    Male 1987-04-18  115163.0  False         Legal
# 6          Ruby  Female 1987-08-17   65476.0   True       Product
# ...         ...     ...        ...       ...    ...           ...
# 995       Henry     NaN 2014-11-23  132483.0  False  Distribution
# 997     Russell    Male 2013-05-20   96914.0  False       Product
# 998       Larry    Male 2013-04-20   60500.0  False  Business Dev
# 999      Albert    Male 2012-05-15  129949.0   True         Sales
# 1000        NaN     NaN        NaT       NaN    NaN           NaN
#
# [899 rows x 6 columns]

# %%
ep[ep['Mgmt'] == True]
# Out:
#     First Name  Gender Start Date    Salary  Mgmt         Team
# 0      Douglas    Male 1993-08-06       NaN  True    Marketing
# 1       Thomas    Male 1996-03-31   61933.0  True          NaN
# 3        Jerry     NaN 2005-03-04  138705.0  True      Finance
# 4        Larry    Male 1998-01-24  101004.0  True           IT
# 6         Ruby  Female 1987-08-17   65476.0  True      Product
# ..         ...     ...        ...       ...   ...          ...
# 991       Rose  Female 2002-08-25  134505.0  True    Marketing
# 992    Anthony    Male 2011-10-16  112769.0  True      Finance
# 993       Tina  Female 1997-05-15   56450.0  True  Engineering
# 994     George    Male 2013-06-21   98874.0  True    Marketing
# 999     Albert    Male 2012-05-15  129949.0  True        Sales
#
# [468 rows x 6 columns]

# %%
high_salary = ep['Salary'] > 100000
ep[high_salary]
# Out:
#     First Name  Gender Start Date    Salary   Mgmt          Team
# 2        Maria  Female        NaT  130590.0  False       Finance
# 3        Jerry     NaN 2005-03-04  138705.0   True       Finance
# 4        Larry    Male 1998-01-24  101004.0   True            IT
# 5       Dennis    Male 1987-04-18  115163.0  False         Legal
# 9      Frances  Female 2002-08-08  139852.0   True  Business Dev
# ..         ...     ...        ...       ...    ...           ...
# 990      Robin  Female 1987-07-24  100765.0   True            IT
# 991       Rose  Female 2002-08-25  134505.0   True     Marketing
# 992    Anthony    Male 2011-10-16  112769.0   True       Finance
# 995      Henry     NaN 2014-11-23  132483.0  False  Distribution
# 999     Albert    Male 2012-05-15  129949.0   True         Sales
#
# [409 rows x 6 columns]

# %%
is_female = ep['Gender'] == 'Female'
in_finance = ep['Team'] == 'Finance'

ep[is_female & in_finance]
# Out:
#     First Name  Gender Start Date    Salary   Mgmt     Team
# 2        Maria  Female        NaT  130590.0  False  Finance
# 7          NaN  Female 2015-07-20   45906.0    NaN  Finance
# 14    Kimberly  Female 1999-01-14   41426.0   True  Finance
# 67      Rachel  Female 1999-08-16   51178.0   True  Finance
# 84       Doris  Female 2004-08-20   83072.0  False  Finance
# 96     Cynthia  Female 1994-03-21  142321.0  False  Finance
# 100    Melissa  Female 2005-06-21   48109.0  False  Finance
# 103    Phyllis  Female 1996-10-11  136984.0   True  Finance
# 105      Kathy  Female 1996-03-09   91712.0  False  Finance
# 142  Elizabeth  Female 2003-10-09  146129.0  False  Finance
# 160      Kathy  Female 2000-03-18  149563.0   True  Finance
# 172       Sara  Female 1991-09-23   97058.0  False  Finance
# 179    Jessica  Female 1995-10-23   68759.0   True  Finance
# 190      Carol  Female 1996-03-19   57783.0  False  Finance
# 226      Kathy  Female 1995-04-19   50905.0   True  Finance
# ...

# %%
ep[is_female | in_finance]
# Out:
#     First Name  Gender Start Date    Salary   Mgmt         Team
# 2        Maria  Female        NaT  130590.0  False      Finance
# 3        Jerry     NaN 2005-03-04  138705.0   True      Finance
# 6         Ruby  Female 1987-08-17   65476.0   True      Product
# 7          NaN  Female 2015-07-20   45906.0    NaN      Finance
# 8       Angela  Female 2005-11-22   95570.0   True  Engineering
# ..         ...     ...        ...       ...    ...          ...
# 990      Robin  Female 1987-07-24  100765.0   True           IT
# 991       Rose  Female 2002-08-25  134505.0   True    Marketing
# 992    Anthony    Male 2011-10-16  112769.0   True      Finance
# 993       Tina  Female 1997-05-15   56450.0   True  Engineering
# 996    Phillip    Male 1984-01-31   42392.0  False      Finance
#
# [489 rows x 6 columns]

# %%
is_female
# Out:
# 0       False
# 1       False
# 2        True
# 3       False
# 4       False
#         ...
# 996     False
# 997     False
# 998     False
# 999     False
# 1000    False
# Name: Gender, Length: 1001, dtype: bool

# %%
~is_female
# Out:
# 0        True
# 1        True
# 2       False
# 3        True
# 4        True
#         ...
# 996      True
# 997      True
# 998      True
# 999      True
# 1000     True
# Name: Gender, Length: 1001, dtype: bool

# %%
ep[~is_female & in_finance] # not female or in finance team
# Out:
#       First Name Gender Start Date    Salary   Mgmt     Team
# 3          Jerry    NaN 2005-03-04  138705.0   True  Finance
# 46         Bruce   Male 2009-11-28  114796.0  False  Finance
# 53          Alan    NaN 2014-03-03   40341.0   True  Finance
# 56          Carl   Male 2006-05-03  130276.0   True  Finance
# 68          Jose   Male 2004-10-30   84834.0   True  Finance
# 69         Irene    NaN 2015-07-14  100863.0   True  Finance
# 83         Shawn   Male 2005-09-23  148115.0   True  Finance
# 117       Steven   Male 1995-03-01  109095.0  False  Finance
# 153       Victor    NaN 2011-03-10   84546.0   True  Finance
# 200         Gary   Male 1987-08-12   89661.0  False  Finance
# 205      Brandon   Male 2006-03-27  115711.0   True  Finance
# 218      Gregory    NaN 1992-06-15   98865.0   True  Finance
# 219        Billy   Male 1995-03-13  120444.0   True  Finance
# 222        Jason   Male 1999-10-17   78417.0  False  Finance
# ...

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
ep[ep['Team'].eq('Finance')]
# Out:
#     First Name  Gender Start Date    Salary   Mgmt     Team
# 2        Maria  Female        NaT  130590.0  False  Finance
# 3        Jerry     NaN 2005-03-04  138705.0   True  Finance
# 7          NaN  Female 2015-07-20   45906.0    NaN  Finance
# 14    Kimberly  Female 1999-01-14   41426.0   True  Finance
# 46       Bruce    Male 2009-11-28  114796.0  False  Finance
# ..         ...     ...        ...       ...    ...      ...
# 907  Elizabeth  Female 1998-07-27  137144.0  False  Finance
# 954        Joe    Male 1980-01-19  119667.0   True  Finance
# 987     Gloria  Female 2014-12-08  136709.0   True  Finance
# 992    Anthony    Male 2011-10-16  112769.0   True  Finance
# 996    Phillip    Male 1984-01-31   42392.0  False  Finance
#
# [102 rows x 6 columns]

# %%
ep[ep['Team'].ne('Finance')]
# Out:
#      First Name  Gender Start Date    Salary   Mgmt          Team
# 0       Douglas    Male 1993-08-06       NaN   True     Marketing
# 1        Thomas    Male 1996-03-31   61933.0   True           NaN
# 4         Larry    Male 1998-01-24  101004.0   True            IT
# 5        Dennis    Male 1987-04-18  115163.0  False         Legal
# 6          Ruby  Female 1987-08-17   65476.0   True       Product
# ...         ...     ...        ...       ...    ...           ...
# 995       Henry     NaN 2014-11-23  132483.0  False  Distribution
# 997     Russell    Male 2013-05-20   96914.0  False       Product
# 998       Larry    Male 2013-04-20   60500.0  False  Business Dev
# 999      Albert    Male 2012-05-15  129949.0   True         Sales
# 1000        NaN     NaN        NaT       NaN    NaN           NaN
#
# [899 rows x 6 columns]

# %%
ep[ep['Salary'].gt(100000)]
# Out:
#     First Name  Gender Start Date    Salary   Mgmt          Team
# 2        Maria  Female        NaT  130590.0  False       Finance
# 3        Jerry     NaN 2005-03-04  138705.0   True       Finance
# 4        Larry    Male 1998-01-24  101004.0   True            IT
# 5       Dennis    Male 1987-04-18  115163.0  False         Legal
# 9      Frances  Female 2002-08-08  139852.0   True  Business Dev
# ..         ...     ...        ...       ...    ...           ...
# 990      Robin  Female 1987-07-24  100765.0   True            IT
# 991       Rose  Female 2002-08-25  134505.0   True     Marketing
# 992    Anthony    Male 2011-10-16  112769.0   True       Finance
# 995      Henry     NaN 2014-11-23  132483.0  False  Distribution
# 999     Albert    Male 2012-05-15  129949.0   True         Sales
#
# [409 rows x 6 columns]

# %%
ep[ep['Salary'].le(100000)]
# Out:
#     First Name  Gender Start Date   Salary   Mgmt          Team
# 1       Thomas    Male 1996-03-31  61933.0   True           NaN
# 6         Ruby  Female 1987-08-17  65476.0   True       Product
# 7          NaN  Female 2015-07-20  45906.0    NaN       Finance
# 8       Angela  Female 2005-11-22  95570.0   True   Engineering
# 10      Louise  Female 1980-08-12  63241.0   True           NaN
# ..         ...     ...        ...      ...    ...           ...
# 993       Tina  Female 1997-05-15  56450.0   True   Engineering
# 994     George    Male 2013-06-21  98874.0   True     Marketing
# 996    Phillip    Male 1984-01-31  42392.0  False       Finance
# 997    Russell    Male 2013-05-20  96914.0  False       Product
# 998      Larry    Male 2013-04-20  60500.0  False  Business Dev
#
# [590 rows x 6 columns]

# %%
ep[ep['Team'].isin(['Marketing', 'Finance', 'Product'])]
# Out:
#     First Name  Gender Start Date    Salary   Mgmt       Team
# 0      Douglas    Male 1993-08-06       NaN   True  Marketing
# 2        Maria  Female        NaT  130590.0  False    Finance
# 3        Jerry     NaN 2005-03-04  138705.0   True    Finance
# 6         Ruby  Female 1987-08-17   65476.0   True    Product
# 7          NaN  Female 2015-07-20   45906.0    NaN    Finance
# ..         ...     ...        ...       ...    ...        ...
# 991       Rose  Female 2002-08-25  134505.0   True  Marketing
# 992    Anthony    Male 2011-10-16  112769.0   True    Finance
# 994     George    Male 2013-06-21   98874.0   True  Marketing
# 996    Phillip    Male 1984-01-31   42392.0  False    Finance
# 997    Russell    Male 2013-05-20   96914.0  False    Product
#
# [295 rows x 6 columns]

# %%
ep[ep['Salary'].between(80000,90000)]
# Out:
#     First Name  Gender Start Date   Salary   Mgmt         Team
# 19       Donna  Female 2010-07-22  81014.0  False      Product
# 31       Joyce     NaN 2005-02-20  88657.0  False      Product
# 35     Theresa  Female 2006-10-10  85182.0  False        Sales
# 45       Roger    Male 1980-04-17  88010.0   True        Sales
# 54        Sara  Female 2007-08-15  83677.0  False  Engineering
# ..         ...     ...        ...      ...    ...          ...
# 930      Nancy  Female 2001-09-10  85213.0   True    Marketing
# 956    Beverly  Female 1986-10-17  80838.0  False  Engineering
# 963        Ann  Female 1994-09-23  89443.0   True        Sales
# 985    Stephen     NaN 1983-07-10  85668.0  False        Legal
# 986      Donna  Female 1982-11-26  82871.0  False    Marketing
#
# [94 rows x 6 columns]

# %%
ep[ep['Start Date'].between(left = '1980-01-01', right = '1990-01-01')]
# Out:
#     First Name  Gender Start Date    Salary   Mgmt         Team
# 5       Dennis    Male 1987-04-18  115163.0  False        Legal
# 6         Ruby  Female 1987-08-17   65476.0   True      Product
# 10      Louise  Female 1980-08-12   63241.0   True          NaN
# 12     Brandon    Male 1980-12-01  112807.0   True           HR
# 17       Shawn    Male 1986-12-07  111737.0  False      Product
# ..         ...     ...        ...       ...    ...          ...
# 983       John    Male 1982-12-23  146907.0  False  Engineering
# 985    Stephen     NaN 1983-07-10   85668.0  False        Legal
# 986      Donna  Female 1982-11-26   82871.0  False    Marketing
# 990      Robin  Female 1987-07-24  100765.0   True           IT
# 996    Phillip    Male 1984-01-31   42392.0  False      Finance
#
# [240 rows x 6 columns]

# %%
ep[ep['First Name'].between('R', 'T')]
# Out:
#     First Name  Gender Start Date    Salary   Mgmt          Team
# 6         Ruby  Female 1987-08-17   65476.0   True       Product
# 17       Shawn    Male 1986-12-07  111737.0  False       Product
# 27       Scott     NaN 1991-07-11  122367.0  False         Legal
# 36      Rachel  Female 2009-02-16  142032.0  False  Business Dev
# 38   Stephanie  Female 1986-09-13   36844.0   True  Business Dev
# ..         ...     ...        ...       ...    ...           ...
# 982       Rose  Female 1982-04-06   91411.0   True            HR
# 985    Stephen     NaN 1983-07-10   85668.0  False         Legal
# 990      Robin  Female 1987-07-24  100765.0   True            IT
# 991       Rose  Female 2002-08-25  134505.0   True     Marketing
# 997    Russell    Male 2013-05-20   96914.0  False       Product
#
# [168 rows x 6 columns]

# %%
ep[ep['Team'].isnull()]
# Out:
#        First Name  Gender Start Date    Salary   Mgmt Team
# 1          Thomas    Male 1996-03-31   61933.0   True  NaN
# 10         Louise  Female 1980-08-12   63241.0   True  NaN
# 23            NaN    Male 2012-06-14  125792.0    NaN  NaN
# 32            NaN    Male 1998-08-21  122340.0    NaN  NaN
# 91          James     NaN 2005-01-26  128771.0  False  NaN
# 109   Christopher    Male 2000-04-22   37919.0  False  NaN
# 139           NaN  Female 1990-10-03  132373.0    NaN  NaN
# 199      Jonathan    Male 2009-07-17  130581.0   True  NaN
# 258       Michael    Male 2002-01-24   43586.0  False  NaN
# 290        Jeremy    Male 1988-06-14  129460.0   True  NaN
# 314         Bobby    Male 1996-03-31  112117.0  False  NaN
# 367        Edward    Male 1989-08-04   66067.0   True  NaN
# 382           NaN  Female 1996-04-18  107024.0    NaN  NaN
# 434         Joyce  Female 1995-02-07   50701.0   True  NaN
# 438         Jason    Male 1998-11-20   69244.0   True  NaN
# ...

# %%
ep[ep['Team'].notnull()] # equals to ep[~ep['Team'].isnull()]
# Out:
#     First Name  Gender Start Date    Salary   Mgmt          Team
# 0      Douglas    Male 1993-08-06       NaN   True     Marketing
# 2        Maria  Female        NaT  130590.0  False       Finance
# 3        Jerry     NaN 2005-03-04  138705.0   True       Finance
# 4        Larry    Male 1998-01-24  101004.0   True            IT
# 5       Dennis    Male 1987-04-18  115163.0  False         Legal
# ..         ...     ...        ...       ...    ...           ...
# 995      Henry     NaN 2014-11-23  132483.0  False  Distribution
# 996    Phillip    Male 1984-01-31   42392.0  False       Finance
# 997    Russell    Male 2013-05-20   96914.0  False       Product
# 998      Larry    Male 2013-04-20   60500.0  False  Business Dev
# 999     Albert    Male 2012-05-15  129949.0   True         Sales
#
# [957 rows x 6 columns]

# %%
ep.dropna() # remoes rows that have at least one Nan
# Out:
#     First Name  Gender Start Date    Salary   Mgmt          Team
# 4        Larry    Male 1998-01-24  101004.0   True            IT
# 5       Dennis    Male 1987-04-18  115163.0  False         Legal
# 6         Ruby  Female 1987-08-17   65476.0   True       Product
# 8       Angela  Female 2005-11-22   95570.0   True   Engineering
# 9      Frances  Female 2002-08-08  139852.0   True  Business Dev
# ..         ...     ...        ...       ...    ...           ...
# 994     George    Male 2013-06-21   98874.0   True     Marketing
# 996    Phillip    Male 1984-01-31   42392.0  False       Finance
# 997    Russell    Male 2013-05-20   96914.0  False       Product
# 998      Larry    Male 2013-04-20   60500.0  False  Business Dev
# 999     Albert    Male 2012-05-15  129949.0   True         Sales
#
# [761 rows x 6 columns]

# %%
ep.dropna(how='all') # default is how = 'any'
# Out:
#     First Name  Gender Start Date    Salary   Mgmt          Team
# 0      Douglas    Male 1993-08-06       NaN   True     Marketing
# 1       Thomas    Male 1996-03-31   61933.0   True           NaN
# 2        Maria  Female        NaT  130590.0  False       Finance
# 3        Jerry     NaN 2005-03-04  138705.0   True       Finance
# 4        Larry    Male 1998-01-24  101004.0   True            IT
# ..         ...     ...        ...       ...    ...           ...
# 995      Henry     NaN 2014-11-23  132483.0  False  Distribution
# 996    Phillip    Male 1984-01-31   42392.0  False       Finance
# 997    Russell    Male 2013-05-20   96914.0  False       Product
# 998      Larry    Male 2013-04-20   60500.0  False  Business Dev
# 999     Albert    Male 2012-05-15  129949.0   True         Sales
#
# [1000 rows x 6 columns]

# %%
ep.dropna(subset=['Gender']) # removes rows that gander columns have nan
# Out:
#     First Name  Gender Start Date    Salary   Mgmt          Team
# 0      Douglas    Male 1993-08-06       NaN   True     Marketing
# 1       Thomas    Male 1996-03-31   61933.0   True           NaN
# 2        Maria  Female        NaT  130590.0  False       Finance
# 4        Larry    Male 1998-01-24  101004.0   True            IT
# 5       Dennis    Male 1987-04-18  115163.0  False         Legal
# ..         ...     ...        ...       ...    ...           ...
# 994     George    Male 2013-06-21   98874.0   True     Marketing
# 996    Phillip    Male 1984-01-31   42392.0  False       Finance
# 997    Russell    Male 2013-05-20   96914.0  False       Product
# 998      Larry    Male 2013-04-20   60500.0  False  Business Dev
# 999     Albert    Male 2012-05-15  129949.0   True         Sales
#
# [854 rows x 6 columns]

# %%
ep.dropna(subset=['Gender', 'Start Date']) # removes rows that gander or start date columns have nan
# Out:
#     First Name  Gender Start Date    Salary   Mgmt          Team
# 0      Douglas    Male 1993-08-06       NaN   True     Marketing
# 1       Thomas    Male 1996-03-31   61933.0   True           NaN
# 4        Larry    Male 1998-01-24  101004.0   True            IT
# 5       Dennis    Male 1987-04-18  115163.0  False         Legal
# 6         Ruby  Female 1987-08-17   65476.0   True       Product
# ..         ...     ...        ...       ...    ...           ...
# 994     George    Male 2013-06-21   98874.0   True     Marketing
# 996    Phillip    Male 1984-01-31   42392.0  False       Finance
# 997    Russell    Male 2013-05-20   96914.0  False       Product
# 998      Larry    Male 2013-04-20   60500.0  False  Business Dev
# 999     Albert    Male 2012-05-15  129949.0   True         Sales
#
# [853 rows x 6 columns]

# %%
ep.dropna(thresh=4) # removes rows with les than 4 values
# Out:
#     First Name  Gender Start Date    Salary   Mgmt          Team
# 0      Douglas    Male 1993-08-06       NaN   True     Marketing
# 1       Thomas    Male 1996-03-31   61933.0   True           NaN
# 2        Maria  Female        NaT  130590.0  False       Finance
# 3        Jerry     NaN 2005-03-04  138705.0   True       Finance
# 4        Larry    Male 1998-01-24  101004.0   True            IT
# ..         ...     ...        ...       ...    ...           ...
# 995      Henry     NaN 2014-11-23  132483.0  False  Distribution
# 996    Phillip    Male 1984-01-31   42392.0  False       Finance
# 997    Russell    Male 2013-05-20   96914.0  False       Product
# 998      Larry    Male 2013-04-20   60500.0  False  Business Dev
# 999     Albert    Male 2012-05-15  129949.0   True         Sales
#
# [985 rows x 6 columns]

# %%
ep[ep['Team'].duplicated()]
# Out:
#      First Name  Gender Start Date    Salary   Mgmt          Team
# 3         Jerry     NaN 2005-03-04  138705.0   True       Finance
# 7           NaN  Female 2015-07-20   45906.0    NaN       Finance
# 10       Louise  Female 1980-08-12   63241.0   True           NaN
# 11        Julie  Female 1997-10-26  102508.0   True         Legal
# 14     Kimberly  Female 1999-01-14   41426.0   True       Finance
# ...         ...     ...        ...       ...    ...           ...
# 996     Phillip    Male 1984-01-31   42392.0  False       Finance
# 997     Russell    Male 2013-05-20   96914.0  False       Product
# 998       Larry    Male 2013-04-20   60500.0  False  Business Dev
# 999      Albert    Male 2012-05-15  129949.0   True         Sales
# 1000        NaN     NaN        NaT       NaN    NaN           NaN
#
# [990 rows x 6 columns]

# %%
ep[~ep['Team'].duplicated()]
# Out:
#    First Name  Gender Start Date    Salary   Mgmt          Team
# 0     Douglas    Male 1993-08-06       NaN   True     Marketing
# 1      Thomas    Male 1996-03-31   61933.0   True           NaN
# 2       Maria  Female        NaT  130590.0  False       Finance
# 4       Larry    Male 1998-01-24  101004.0   True            IT
# 5      Dennis    Male 1987-04-18  115163.0  False         Legal
# 6        Ruby  Female 1987-08-17   65476.0   True       Product
# 8      Angela  Female 2005-11-22   95570.0   True   Engineering
# 9     Frances  Female 2002-08-08  139852.0   True  Business Dev
# 12    Brandon    Male 1980-12-01  112807.0   True            HR
# 13       Gary    Male 2008-01-27  109831.0  False         Sales
# 40    Michael    Male 2008-10-10   99283.0   True  Distribution

# %%
ep[~ep['Team'].duplicated(keep='last')] # default iss keep = 'first'
# Out:
#      First Name  Gender Start Date    Salary   Mgmt          Team
# 988       Alice  Female 2004-10-05   47638.0  False            HR
# 989      Justin     NaN 1991-02-10   38344.0  False         Legal
# 990       Robin  Female 1987-07-24  100765.0   True            IT
# 993        Tina  Female 1997-05-15   56450.0   True   Engineering
# 994      George    Male 2013-06-21   98874.0   True     Marketing
# 995       Henry     NaN 2014-11-23  132483.0  False  Distribution
# 996     Phillip    Male 1984-01-31   42392.0  False       Finance
# 997     Russell    Male 2013-05-20   96914.0  False       Product
# 998       Larry    Male 2013-04-20   60500.0  False  Business Dev
# 999      Albert    Male 2012-05-15  129949.0   True         Sales
# 1000        NaN     NaN        NaT       NaN    NaN           NaN

# %%
ep.drop_duplicates() # remove rows that have equal values in all columns
# Out:
#      First Name  Gender Start Date    Salary   Mgmt          Team
# 0       Douglas    Male 1993-08-06       NaN   True     Marketing
# 1        Thomas    Male 1996-03-31   61933.0   True           NaN
# 2         Maria  Female        NaT  130590.0  False       Finance
# 3         Jerry     NaN 2005-03-04  138705.0   True       Finance
# 4         Larry    Male 1998-01-24  101004.0   True            IT
# ...         ...     ...        ...       ...    ...           ...
# 996     Phillip    Male 1984-01-31   42392.0  False       Finance
# 997     Russell    Male 2013-05-20   96914.0  False       Product
# 998       Larry    Male 2013-04-20   60500.0  False  Business Dev
# 999      Albert    Male 2012-05-15  129949.0   True         Sales
# 1000        NaN     NaN        NaT       NaN    NaN           NaN
#
# [1001 rows x 6 columns]

# %%
ep.drop_duplicates(subset=['Team']) # remove rows that have equal values in specified columns
# Out:
#    First Name  Gender Start Date    Salary   Mgmt          Team
# 0     Douglas    Male 1993-08-06       NaN   True     Marketing
# 1      Thomas    Male 1996-03-31   61933.0   True           NaN
# 2       Maria  Female        NaT  130590.0  False       Finance
# 4       Larry    Male 1998-01-24  101004.0   True            IT
# 5      Dennis    Male 1987-04-18  115163.0  False         Legal
# 6        Ruby  Female 1987-08-17   65476.0   True       Product
# 8      Angela  Female 2005-11-22   95570.0   True   Engineering
# 9     Frances  Female 2002-08-08  139852.0   True  Business Dev
# 12    Brandon    Male 1980-12-01  112807.0   True            HR
# 13       Gary    Male 2008-01-27  109831.0  False         Sales
# 40    Michael    Male 2008-10-10   99283.0   True  Distribution

# %%
ep.drop_duplicates(subset=['Team'], keep='last')
# Out:
#      First Name  Gender Start Date    Salary   Mgmt          Team
# 988       Alice  Female 2004-10-05   47638.0  False            HR
# 989      Justin     NaN 1991-02-10   38344.0  False         Legal
# 990       Robin  Female 1987-07-24  100765.0   True            IT
# 993        Tina  Female 1997-05-15   56450.0   True   Engineering
# 994      George    Male 2013-06-21   98874.0   True     Marketing
# 995       Henry     NaN 2014-11-23  132483.0  False  Distribution
# 996     Phillip    Male 1984-01-31   42392.0  False       Finance
# 997     Russell    Male 2013-05-20   96914.0  False       Product
# 998       Larry    Male 2013-04-20   60500.0  False  Business Dev
# 999      Albert    Male 2012-05-15  129949.0   True         Sales
# 1000        NaN     NaN        NaT       NaN    NaN           NaN

# %%
ep.drop_duplicates(subset=['First Name'], keep= False)
# Out:
#     First Name  Gender Start Date    Salary   Mgmt          Team
# 5       Dennis    Male 1987-04-18  115163.0  False         Legal
# 8       Angela  Female 2005-11-22   95570.0   True   Engineering
# 33        Jean  Female 1993-12-18  119082.0  False  Business Dev
# 190      Carol  Female 1996-03-19   57783.0  False       Finance
# 291      Tammy  Female 1984-11-11  132839.0   True            IT
# 495     Eugene    Male 1984-05-24   81077.0  False         Sales
# 688      Brian    Male 2007-04-07   93901.0   True         Legal
# 832      Keith    Male 2003-02-12  120672.0  False         Legal
# 887      David    Male 2009-12-05   92242.0  False         Legal
